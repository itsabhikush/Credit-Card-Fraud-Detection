# %% [markdown]
# ## Dataset Information
#
# The dataset contains transactions made by credit cards in September 2013 by European cardholders. This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
#
# The dataset is characterized by the absence of original features and additional contextual information due to confidentiality constraints. Principal Component Analysis (PCA) has been applied to derive numerical input variables, denoted as V1 through V28. However, two features, 'Time' and 'Amount,' have not undergone PCA transformation. The 'Time' feature signifies the elapsed seconds between each transaction and the initial transaction in the dataset, while the 'Amount' feature denotes the transaction amount. The latter feature can be particularly relevant for methodologies involving example-dependent cost-sensitive learning.
#
# The response variable is represented by the 'Class' feature, taking a value of 1 in cases of fraud and 0 otherwise.
#
# Given the substantial class imbalance, it is recommended to assess accuracy using the Area Under the Precision-Recall Curve (AUPRC). Traditional measures such as the confusion matrix accuracy may not provide meaningful insights in the context of unbalanced classification.

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# statistical information of dataset
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# datatype information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ## Preprocessing the dataset

# %%
# check for null values of given  the dataset
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.countplot(df['Class'])
# Out:
# <Axes: ylabel='count'>

# %%
df_temp = df.drop(columns=['Time', 'Amount', 'Class'], axis=1)

# create distribution plot
fig, ax = plt.subplots(ncols=4, nrows=7, figsize=(20, 50))
index = 0
ax = ax.flatten()

for col in df_temp.columns:
    sns.distplot(df_temp[col], ax=ax[index])
    index += 1
plt.tight_layout(pad=0.5, w_pad=0.5, h_pad=5)

# %%
sns.distplot(df['Time'])
# Out:
# <Axes: xlabel='Time', ylabel='Density'>

# %%
sns.distplot(df['Amount'])
# Out:
# <Axes: xlabel='Amount', ylabel='Density'>

# %% [markdown]
# ## Coorelation Matrix of dataset

# %%
corr = df.corr()
plt.figure(figsize=(30,40))
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ## Input Split

# %%
X = df.drop(columns=['Class'], axis=1)
y = df['Class']

# %% [markdown]
# ## Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaler = sc.fit_transform(X)

# %%
x_scaler[-1]
# Out:
# array([ 1.64205773, -0.27233093, -0.11489898,  0.46386564, -0.35757   ,
#        -0.00908946, -0.48760183,  1.27476937, -0.3471764 ,  0.44253246,
#        -0.84072963, -1.01934641, -0.0315383 , -0.18898634, -0.08795849,
#         0.04515766, -0.34535763, -0.77752147,  0.1997554 , -0.31462479,
#         0.49673933,  0.35541083,  0.8861488 ,  0.6033653 ,  0.01452561,
#        -0.90863123, -1.69685342, -0.00598394,  0.04134999,  0.51435531])

# %% [markdown]
# ## Model Training

# %%
# train test split
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
x_train, x_test, y_train, y_test = train_test_split(x_scaler, y, test_size=0.25, random_state=42, stratify=y)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.85      0.63      0.72       123
#
#     accuracy                           1.00     71202
#    macro avg       0.92      0.81      0.86     71202
# weighted avg       1.00      1.00      1.00     71202
#
# F1 Score: 0.719626168224299

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.95      0.78      0.86       123
#
#     accuracy                           1.00     71202
#    macro avg       0.98      0.89      0.93     71202
# weighted avg       1.00      1.00      1.00     71202
#
# F1 Score: 0.8571428571428571

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_jobs=-1)
# training
model.fit(x_train, y_train)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.95      0.79      0.86       123
#
#     accuracy                           1.00     71202
#    macro avg       0.98      0.89      0.93     71202
# weighted avg       1.00      1.00      1.00     71202
#
# F1 Score: 0.8622222222222222

# %% [markdown]
# ## Class Imbalancement

# %%
sns.countplot(y_train)
# Out:
# <Axes: ylabel='count'>

# %%
# balance the class with equal distribution
from imblearn.over_sampling import SMOTE
over_sample = SMOTE()
x_smote, y_smote = over_sample.fit_resample(x_train, y_train)

# %%
sns.countplot(y_smote)
# Out:
# <Axes: ylabel='count'>

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# training 
model.fit(x_smote, y_smote)
# testing 
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     71079
#            1       0.06      0.89      0.11       123
#
#     accuracy                           0.98     71202
#    macro avg       0.53      0.93      0.55     71202
# weighted avg       1.00      0.98      0.99     71202
#
# F1 Score: 0.1116231438812084

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_jobs=-1)
# training
model.fit(x_smote, y_smote)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.89      0.79      0.84       123
#
#     accuracy                           1.00     71202
#    macro avg       0.94      0.89      0.92     71202
# weighted avg       1.00      1.00      1.00     71202
#
# F1 Score: 0.8362068965517241

# %%
from xgboost import XGBClassifier
model = XGBClassifier(n_jobs=-1)
# training
model.fit(x_smote, y_smote)
# testing
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))
print("F1 Score:",f1_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71079
#            1       0.74      0.83      0.78       123
#
#     accuracy                           1.00     71202
#    macro avg       0.87      0.91      0.89     71202
# weighted avg       1.00      1.00      1.00     71202
#
# F1 Score: 0.7816091954022988
